# %% [markdown]
# # Carregamento de Dados
#
# Objetivos dessa aula:
# * Carregar um dataset customizado
# * Implementar o fluxo de treinamento **e validação** completo de uma rede

# %% [markdown]
# ## Hiperparâmetros
#
# Vamos manter a organização do último script :)
#
# * imports de pacotes
# * configuração de hiperparâmetros
# * definição do hardware padrão utilizado
#
# E bora de GPU de novo!

# %%
import torch
from torch import nn
from torch import optim

from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from sklearn import metrics
from sklearn.preprocessing import StandardScaler

import pandas as pd
import numpy as np
import time
import os


import matplotlib.pyplot as plt
# %matplotlib inline

# Configurando hiperparâmetros.
args = {
    'epoch_num': 200,     # Número de épocas.
    'lr': 5e-5,           # Taxa de aprendizado.
    'weight_decay': 5e-4, # Penalidade L2 (Regularização).
    'num_workers': 3,     # Número de threads do dataloader.
    'batch_size': 20,     # Tamanho do batch.
}

if torch.cuda.is_available():
    args['device'] = torch.device('cuda')
else:
    args['device'] = torch.device('cpu')

print(args['device'])
# Out:
# cuda

# %% [markdown]
# ## Dataset
#
# Dataset de aplicativos para aluguel de bicicletas (*Bike Sharing Dataset*). <br>
# * Dadas algumas informações como velocidade do vento, estação do ano, etc., quantas bicicletas serão alugadas na próxima hora?
#
# Esse é um problema de **Regressão**, onde precisamos estimar uma variável dependente em um espaço contínuo (alugueis de bikes) a partir de um conjunto de variáveis independentes (as condições no momento).

# %% [markdown]
# ### Baixando o dataset
#
# Fonte: https://archive.ics.uci.edu/ml/datasets/Bike+Sharing+Dataset

# %%
! wget https://archive.ics.uci.edu/ml/machine-learning-databases/00275/Bike-Sharing-Dataset.zip
! unzip Bike-Sharing-Dataset.zip
# Out:
# --2023-05-22 12:23:42--  https://archive.ics.uci.edu/ml/machine-learning-databases/00275/Bike-Sharing-Dataset.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 279992 (273K) [application/x-httpd-php]
# Saving to: ‘Bike-Sharing-Dataset.zip’
#
# Bike-Sharing-Datase 100%[===================>] 273.43K  1.42MB/s    in 0.2s
#
# 2023-05-22 12:23:43 (1.42 MB/s) - ‘Bike-Sharing-Dataset.zip’ saved [279992/279992]
#
# Archive:  Bike-Sharing-Dataset.zip
#   inflating: Readme.txt
#   inflating: day.csv
#   inflating: hour.csv

# %% [markdown]
# ### Visualizando os dados

# %%
df = pd.read_csv('hour.csv')
print(len(df))
df.head()
# Out:
# 17379
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# ### Tratamento de dados
#
# **Variáveis Categóricas** <br>
# Como descrito na página do dataset, apenas as variáveis numéricas estão normalizadas. No caso das categóricas (como dia da semana e estação do ano), cada elemento contém o índice da categoria.
#
# Existem várias formas de lidar com variáveis categóricas em uma regressão, mas para não desviar o foco da nossa aula manteremos os valores originais das variáveis categóricas.
#
# **Separação em treino e teste**<br>
#
# Para treinar e validar o nosso modelo, precisamos de dois conjuntos de dados (treino e teste). Para isso, utilizaremos a função ```torch.randperm``` para amostrar aleatoriamente um percentual dos dados, separando-os para validação.
#
# Documentação: https://pytorch.org/docs/stable/torch.html#torch.randperm

# %%
# Train/Test split
torch.manual_seed(1)
indices = torch.randperm(len(df)).tolist()

train_size = int(0.8*len(df))
df_train = df.iloc[indices[:train_size]]
df_test  = df.iloc[indices[train_size:]]

print(len(df_train), len(df_test))
display(df_test.head())

df_train.to_csv('bike_train.csv',index=False)
df_test.to_csv('bike_test.csv',index=False)
# !ls
# Out:
# 13903 3476
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 12663    12664  2012-06-16       2   1     6  20        0        6
# 1801      1802  2011-03-20       1   0     3  18        0        0
# 16567    16568  2012-11-28       4   1    11   1        0        3
# 8817      8818  2012-01-08       1   1     1   5        0        0
# 2608      2609  2011-04-23       2   0     4  14        0        6
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 12663           0           2  0.66  0.6212  0.47     0.1940     123
# 1801            0           1  0.38  0.3939  0.40     0.3582      58
# 16567           1           2  0.26  0.2576  0.75     0.2239       0
# 8817            0           2  0.32  0.3333  0.49     0.1045       0
# 2608            0           1  0.58  0.5455  0.78     0.3582     182
#
#        registered  cnt
# 12663         229  352
# 1801           98  156
# 16567          12   12
# 8817            2    2
# 2608          209  391
# Bike-Sharing-Dataset.zip  bike_train.csv  hour.csv    sample_data
# bike_test.csv		  day.csv	  Readme.txt

# %% [markdown]
# ### Classe Dataset
#
# O pacote ```torch.util.data``` possui a classe abstrata ```Dataset```. Ela permite que você implemente o seu próprio dataset reescrevendo os métodos:
#
# * ```__init__(self)```: Define a lista de amostras do seu dataset
# * ```__getitem__(self, idx)```: Carrega uma amostra, aplica as devidas transformações e retorna uma **tupla ```(dado, rótulo)```**.
# * ```__len__(self)```: Retorna a quantidade de amostras do dataset
#
# Tutorial completo do PyTorch: https://pytorch.org/tutorials/beginner/data_loading_tutorial.html

# %%
class Bicicletinha(Dataset):
  def __init__(self, csv_path, scaler_feat=None, scaler_label=None):
  
    self.dados = pd.read_csv(csv_path).to_numpy()
    
  def __getitem__(self, idx):
    
    sample = self.dados[idx][2:14]
    label  = self.dados[idx][-1:]
    
    # converte para tensor
    sample = torch.from_numpy(sample.astype(np.float32))
    label  = torch.from_numpy(label.astype(np.float32))
    
    return sample, label
    
  def __len__(self):
    return len(self.dados)

# %%
dataset = Bicicletinha('bike_train.csv')
dado, rotulo = dataset[0]
print(rotulo)
print(dado)
# Out:
# tensor([373.])
# tensor([ 4.0000,  1.0000, 11.0000, 19.0000,  0.0000,  4.0000,  1.0000,  1.0000,
#          0.3800,  0.3939,  0.2700,  0.3582])

# %% [markdown]
# ### Construindo conjuntos de treino e teste

# %%
train_set = Bicicletinha('bike_train.csv')
test_set  = Bicicletinha('bike_test.csv')

print('Tamanho do treino: ' + str(len(train_set)) + ' amostras')
print('Tamanho do teste: ' + str(len(test_set)) + ' amostras')
# Out:
# Tamanho do treino: 13903 amostras
# Tamanho do teste: 3476 amostras

# %% [markdown]
# ## Dataloader

# %%
# Criando dataloader
train_loader = DataLoader(train_set,
                          args['batch_size'],
                          num_workers=args['num_workers'],
                          shuffle=True)
test_loader = DataLoader(test_set,
                         args['batch_size'],
                         num_workers=args['num_workers'],
                         shuffle=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %% [markdown]
# O objeto retornado é um **iterador**, podendo ser utilizado para iterar em loops mas não suportando indexação.

# %%
for batch in test_loader:
  
  dado, rotulo = batch
  print('## Dimensionalidade do batch ##')
  print(dado.size(), rotulo.size())
  
  break
# Out:
# ## Dimensionalidade do batch ##
# torch.Size([20, 12]) torch.Size([20, 1])

# %% [markdown]
# ## Implementando o MLP
#
# Essa parte aqui você já tira de letra! Minha sugestão é construir um modelo com:
#
# * **Duas camadas escondidas**. Lembre-se de alternar as camadas com ativações não-lineares.
# * Uma camada de saída (com qual ativação?)

# %%
class MLP(nn.Module):
  
  def __init__(self, input_size, hidden_size, out_size):
    super(MLP, self).__init__()
    
    self.features = nn.Sequential(
          nn.Linear(input_size, hidden_size),
          nn.ReLU(),
          nn.Linear(hidden_size, hidden_size),
          nn.ReLU(),
    )
    
    self.classifier = nn.Sequential(
        nn.Linear(hidden_size, out_size),
        nn.ReLU(),
    )

  def forward(self, X):
    
    hidden = self.features(X)
    output = self.classifier(hidden)
    
    return output

input_size  = train_set[0][0].size(0)
hidden_size = 128
out_size    = 1

net = MLP(input_size, hidden_size, out_size).to(args['device'])
print(net)
# Out:
# MLP(
#   (features): Sequential(
#     (0): Linear(in_features=12, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=128, out_features=1, bias=True)
#     (1): ReLU()
#   )
# )

# %% [markdown]
# ## Definindo loss e otimizador
#
# Se lembra quais as funções de perda adequadas para um problema de regressão?

# %%
criterion = nn.L1Loss().to(args['device'])

optimizer = optim.Adam(net.parameters(), lr=args['lr'], weight_decay=args['weight_decay'])

# %% [markdown]
# # Fluxo de Treinamento & Validação
#
# ## Treinamento
#
# Relembrando o passo a passo do fluxo de treinamento:
# * Iterar nas épocas
# * Iterar nos batches
# * Cast dos dados no dispositivo de hardware
# * Forward na rede e cálculo da loss
# * Cálculo do gradiente e atualização dos pesos
#
# Esse conjunto de passos é responsável pelo processo iterativo de otimização de uma rede. **A validação** por outro lado, é apenas a aplicação da rede em dados nunca antes visto para estimar a qualidade do modelo no mundo real.
#
# ## Validação
#
# Para essa etapa, o PyTorch oferece dois artifícios:
# * ```model.eval()```: Impacta no *forward* da rede, informando as camadas caso seu comportamento mude entre fluxos (ex: dropout).
# * ```with torch.no_grad()```: Gerenciador de contexto que desabilita o cálculo e armazenamento de gradientes (economia de tempo e memória). Todo o código de validação deve ser executado dentro desse contexto.
#
# Exemplo de código para validação
#
# ```python
# net.eval()
# with torch.no_grad():
#   for batch in test_loader:
#       # Código de validação
# ```
#
# Existe o equivalente ao ```model.eval()``` para explicitar que a sua rede deve estar em modo de treino, é o ```model.train()```. Apesar de ser o padrão dos modelos, é boa prática definir também o modo de treinamento.

# %%
def train(train_loader, net, epoch):

  # Training mode
  net.train()
  
  start = time.time()
  
  epoch_loss  = []
  for batch in train_loader:
    
    dado, rotulo = batch
    
    # Cast do dado na GPU
    dado = dado.to(args['device'])
    rotulo = rotulo.to(args['device'])
    
    # Forward
    ypred = net(dado)
    loss = criterion(ypred, rotulo)
    epoch_loss.append(loss.cpu().data)
    
    # Backpropagation
    loss.backward()
    optimizer.step()
   
  epoch_loss = np.asarray(epoch_loss)
  
  end = time.time()
  print('#################### Train ####################')
  print('Epoch %d, Loss: %.4f +/- %.4f, Time: %.2f' % (epoch, epoch_loss.mean(), epoch_loss.std(), end-start))
  
  return epoch_loss.mean()

# %%
def validate(test_loader, net, epoch):

  # Evaluation mode
  net.eval()
  
  start = time.time()
  
  epoch_loss  = []
  
  with torch.no_grad(): 
    for batch in test_loader:

      dado, rotulo = batch

      # Cast do dado na GPU
      dado = dado.to(args['device'])
      rotulo = rotulo.to(args['device'])

      # Forward
      ypred = net(dado)
      loss = criterion(ypred, rotulo)
      epoch_loss.append(loss.cpu().data)

  epoch_loss = np.asarray(epoch_loss)
  
  end = time.time()
  print('********** Validate **********')
  print('Epoch %d, Loss: %.4f +/- %.4f, Time: %.2f\n' % (epoch, epoch_loss.mean(), epoch_loss.std(), end-start))
  
  return epoch_loss.mean()

# %%
train_losses, test_losses = [], []
for epoch in range(args['epoch_num']):
  
  # Train
  train_losses.append(train(train_loader, net, epoch))
  
  # Validate
  test_losses.append(validate(test_loader, net, epoch))
# Out:
# #################### Train ####################
# Epoch 0, Loss: 164.3138 +/- 42.0975, Time: 5.17
# ********** Validate **********
# Epoch 0, Loss: 125.7965 +/- 30.3890, Time: 0.44
#
# #################### Train ####################
# Epoch 1, Loss: 130.6107 +/- 25.6430, Time: 2.49
# ********** Validate **********
# Epoch 1, Loss: 126.6351 +/- 24.3811, Time: 0.65
#
# #################### Train ####################
# Epoch 2, Loss: 122.8896 +/- 30.2196, Time: 2.25
# ********** Validate **********
# Epoch 2, Loss: 125.2943 +/- 31.5335, Time: 0.45
#
# #################### Train ####################
# Epoch 3, Loss: 120.4436 +/- 31.0856, Time: 2.16
# ********** Validate **********
# Epoch 3, Loss: 117.2516 +/- 26.3097, Time: 0.46
#
# #################### Train ####################
# Epoch 4, Loss: 118.8115 +/- 24.6739, Time: 2.14
# ********** Validate **********
# Epoch 4, Loss: 114.5222 +/- 28.4489, Time: 0.43
#
# #################### Train ####################
# Epoch 5, Loss: 118.3620 +/- 31.7777, Time: 2.13
# ********** Validate **********
# Epoch 5, Loss: 115.1214 +/- 29.4287, Time: 0.48
#
# #################### Train ####################
# Epoch 6, Loss: 115.6204 +/- 27.2289, Time: 2.60
# ********** Validate **********
# Epoch 6, Loss: 114.4765 +/- 26.8682, Time: 0.44
#
# #################### Train ####################
# Epoch 7, Loss: 113.9728 +/- 27.5468, Time: 2.21
# ********** Validate **********
# Epoch 7, Loss: 111.4902 +/- 28.6821, Time: 0.45
#
# #################### Train ####################
# Epoch 8, Loss: 111.6952 +/- 25.9599, Time: 2.17
# ********** Validate **********
# Epoch 8, Loss: 108.0174 +/- 26.1615, Time: 0.44
#
# #################### Train ####################
# Epoch 9, Loss: 107.8571 +/- 28.5970, Time: 2.15
# ********** Validate **********
# Epoch 9, Loss: 104.4417 +/- 26.1539, Time: 0.46
#
# #################### Train ####################
# Epoch 10, Loss: 103.9991 +/- 24.9886, Time: 2.51
# ********** Validate **********
# Epoch 10, Loss: 100.6571 +/- 26.5733, Time: 0.62
#
# #################### Train ####################
# Epoch 11, Loss: 99.7821 +/- 24.9275, Time: 2.21
# ********** Validate **********
# Epoch 11, Loss: 95.8669 +/- 24.1808, Time: 0.45
#
# #################### Train ####################
# Epoch 12, Loss: 96.6053 +/- 24.3821, Time: 2.21
# ********** Validate **********
# Epoch 12, Loss: 95.3180 +/- 23.4885, Time: 0.46
#
# #################### Train ####################
# Epoch 13, Loss: 96.5437 +/- 24.5865, Time: 2.15
# ********** Validate **********
# Epoch 13, Loss: 93.7652 +/- 22.9804, Time: 0.46
#
# #################### Train ####################
# Epoch 14, Loss: 94.7331 +/- 23.7863, Time: 2.15
# ********** Validate **********
# Epoch 14, Loss: 90.6605 +/- 22.7364, Time: 0.59
#
# #################### Train ####################
# Epoch 15, Loss: 92.5012 +/- 22.5406, Time: 2.68
# ********** Validate **********
# Epoch 15, Loss: 90.1325 +/- 24.0752, Time: 0.44
#
# #################### Train ####################
# Epoch 16, Loss: 92.0726 +/- 23.4139, Time: 2.18
# ********** Validate **********
# Epoch 16, Loss: 91.1649 +/- 24.7383, Time: 0.46
#
# #################### Train ####################
# Epoch 17, Loss: 91.9021 +/- 22.9712, Time: 2.12
# ********** Validate **********
# Epoch 17, Loss: 90.4718 +/- 23.9693, Time: 0.45
#
# #################### Train ####################
# Epoch 18, Loss: 91.7303 +/- 23.8266, Time: 2.21
# ********** Validate **********
# Epoch 18, Loss: 88.4730 +/- 23.3559, Time: 0.44
#
# #################### Train ####################
# Epoch 19, Loss: 90.9303 +/- 22.6189, Time: 2.67
# ********** Validate **********
# Epoch 19, Loss: 87.4573 +/- 21.6343, Time: 0.52
#
# #################### Train ####################
# Epoch 20, Loss: 90.8817 +/- 22.9866, Time: 2.14
# ********** Validate **********
# Epoch 20, Loss: 87.1134 +/- 21.7074, Time: 0.43
#
# #################### Train ####################
# Epoch 21, Loss: 90.1984 +/- 23.8131, Time: 2.13
# ********** Validate **********
# Epoch 21, Loss: 86.2803 +/- 23.5902, Time: 0.46
#
# #################### Train ####################
# Epoch 22, Loss: 89.6665 +/- 22.8829, Time: 2.18
# ********** Validate **********
# Epoch 22, Loss: 89.7225 +/- 25.4991, Time: 0.46
#
# #################### Train ####################
# Epoch 23, Loss: 88.9139 +/- 23.0157, Time: 2.29
# ********** Validate **********
# Epoch 23, Loss: 88.4843 +/- 24.9369, Time: 0.67
#
# #################### Train ####################
# Epoch 24, Loss: 89.5620 +/- 24.2184, Time: 2.46
# ********** Validate **********
# Epoch 24, Loss: 87.1714 +/- 21.9373, Time: 0.46
#
# #################### Train ####################
# Epoch 25, Loss: 88.9055 +/- 24.6149, Time: 2.16
# ********** Validate **********
# Epoch 25, Loss: 90.6821 +/- 21.4123, Time: 0.44
#
# #################### Train ####################
# Epoch 26, Loss: 88.3255 +/- 23.1759, Time: 2.14
# ********** Validate **********
# Epoch 75, Loss: 66.2144 +/- 20.5203, Time: 0.50
#
# #################### Train ####################
# Epoch 76, Loss: 68.1373 +/- 18.8464, Time: 2.70
# ********** Validate **********
# Epoch 76, Loss: 64.1548 +/- 18.1509, Time: 0.46
#
# #################### Train ####################
# Epoch 77, Loss: 66.8084 +/- 19.2616, Time: 2.21
# ********** Validate **********
# Epoch 77, Loss: 67.3941 +/- 18.0755, Time: 0.47
#
# #################### Train ####################
# Epoch 78, Loss: 66.6582 +/- 18.6109, Time: 2.20
# ********** Validate **********
# Epoch 78, Loss: 64.6709 +/- 17.2237, Time: 0.46
#
# #################### Train ####################
# Epoch 79, Loss: 67.2703 +/- 18.1713, Time: 2.19
# ********** Validate **********
# Epoch 79, Loss: 62.4649 +/- 18.5331, Time: 0.47
#
# #################### Train ####################
# Epoch 80, Loss: 66.8323 +/- 18.7523, Time: 2.53
# ********** Validate **********
# Epoch 80, Loss: 66.7640 +/- 20.4358, Time: 0.66
#
# #################### Train ####################
# Epoch 81, Loss: 65.9734 +/- 17.9702, Time: 2.18
# ********** Validate **********
# Epoch 81, Loss: 64.2532 +/- 19.5966, Time: 0.46
#
# #################### Train ####################
# Epoch 82, Loss: 67.1807 +/- 18.1010, Time: 2.18
# ********** Validate **********
# Epoch 82, Loss: 65.9545 +/- 16.9635, Time: 0.45
#
# #################### Train ####################
# Epoch 83, Loss: 65.8547 +/- 19.4868, Time: 2.20
# ********** Validate **********
# Epoch 83, Loss: 65.9410 +/- 17.8889, Time: 0.45
#
# #################### Train ####################
# Epoch 84, Loss: 67.5497 +/- 18.6728, Time: 2.76
# ********** Validate **********
# Epoch 84, Loss: 66.4052 +/- 20.0881, Time: 1.06
#
# #################### Train ####################
# Epoch 85, Loss: 66.1151 +/- 18.2339, Time: 2.41
# ********** Validate **********
# Epoch 85, Loss: 63.5548 +/- 19.2008, Time: 0.45
#
# #################### Train ####################
# Epoch 86, Loss: 66.0381 +/- 17.5276, Time: 2.17
# ********** Validate **********
# Epoch 86, Loss: 67.3738 +/- 17.0433, Time: 0.46
#
# #################### Train ####################
# Epoch 87, Loss: 65.5988 +/- 18.9607, Time: 2.18
# ********** Validate **********
# Epoch 87, Loss: 63.3397 +/- 19.0395, Time: 0.51
#
# #################### Train ####################
# Epoch 88, Loss: 63.9458 +/- 17.3837, Time: 2.18
# ********** Validate **********
# Epoch 88, Loss: 62.9018 +/- 18.2845, Time: 0.58
#
# #################### Train ####################
# Epoch 89, Loss: 63.6938 +/- 17.2530, Time: 2.63
# ********** Validate **********
# Epoch 89, Loss: 62.7375 +/- 18.0592, Time: 0.47
#
# #################### Train ####################
# Epoch 90, Loss: 62.8407 +/- 16.1421, Time: 2.13
# ********** Validate **********
# Epoch 90, Loss: 62.0928 +/- 16.4140, Time: 0.45
#
# #################### Train ####################
# Epoch 91, Loss: 62.9520 +/- 16.8721, Time: 2.19
# ********** Validate **********
# Epoch 91, Loss: 60.0071 +/- 16.9971, Time: 0.47
#
# #################### Train ####################
# Epoch 92, Loss: 62.2140 +/- 16.7842, Time: 2.19
# ********** Validate **********
# Epoch 92, Loss: 60.7752 +/- 17.7367, Time: 0.47
#
# #################### Train ####################
# Epoch 93, Loss: 61.8459 +/- 17.2762, Time: 2.61
# ********** Validate **********
# Epoch 93, Loss: 61.0766 +/- 17.1653, Time: 0.59
#
# #################### Train ####################
# Epoch 94, Loss: 61.5563 +/- 16.5296, Time: 2.20
# ********** Validate **********
# Epoch 94, Loss: 61.1367 +/- 17.6947, Time: 0.47
#
# #################### Train ####################
# Epoch 95, Loss: 61.9902 +/- 17.4197, Time: 2.24
# ********** Validate **********
# Epoch 95, Loss: 61.4760 +/- 17.1749, Time: 0.45
#
# #################### Train ####################
# Epoch 96, Loss: 61.8826 +/- 16.7699, Time: 2.22
# ********** Validate **********
# Epoch 96, Loss: 59.9919 +/- 16.8327, Time: 0.47
#
# #################### Train ####################
# Epoch 97, Loss: 61.4798 +/- 17.0385, Time: 2.34
# ********** Validate **********
# Epoch 97, Loss: 60.9255 +/- 16.4949, Time: 0.68
#
# #################### Train ####################
# Epoch 98, Loss: 60.9446 +/- 16.2015, Time: 2.42
# ********** Validate **********
# Epoch 98, Loss: 61.1807 +/- 16.0651, Time: 0.46
#
# #################### Train ####################
# Epoch 99, Loss: 60.6523 +/- 16.6950, Time: 2.20
# ********** Validate **********
# Epoch 99, Loss: 60.8282 +/- 16.3503, Time: 0.47
#
# #################### Train ####################
# Epoch 100, Loss: 60.0836 +/- 16.1998, Time: 2.17
# ********** Validate **********
# Epoch 100, Loss: 59.6546 +/- 16.0856, Time: 0.45
#
# #################### Train ####################
# Epoch 101, Loss: 59.9991 +/- 16.0887, Time: 2.21
# ********** Validate **********
# Epoch 101, Loss: 59.1624 +/- 16.1969, Time: 0.48
#
# #################### Train ####################
# Epoch 102, Loss: 59.7465 +/- 15.7212, Time: 2.71
# ********** Validate **********
# Epoch 102, Loss: 59.0114 +/- 17.3241, Time: 0.45
#
# #################### Train ####################
# Epoch 103, Loss: 59.6920 +/- 16.1062, Time: 2.23
# ********** Validate **********
# Epoch 103, Loss: 57.9176 +/- 16.5330, Time: 0.50
#
# #################### Train ####################
# Epoch 104, Loss: 59.1607 +/- 15.9570, Time: 2.23
# ********** Validate **********
# Epoch 104, Loss: 58.2599 +/- 16.6368, Time: 0.48
#
# #################### Train ####################
# Epoch 105, Loss: 59.3543 +/- 16.3761, Time: 2.16
# ********** Validate **********
# Epoch 105, Loss: 58.1922 +/- 17.7676, Time: 0.47
#
# #################### Train ####################
# Epoch 106, Loss: 58.7688 +/- 17.1465, Time: 2.57
# ********** Validate **********
# Epoch 106, Loss: 58.0099 +/- 17.4843, Time: 0.68
#
# #################### Train ####################
# Epoch 107, Loss: 58.0823 +/- 15.5308, Time: 2.23
# ********** Validate **********
# Epoch 107, Loss: 57.8253 +/- 17.0213, Time: 0.47
#
# Epoch 140, Loss: 55.7768 +/- 15.9198, Time: 0.45
#
# #################### Train ####################
# Epoch 141, Loss: 53.8326 +/- 14.3576, Time: 2.69
# ********** Validate **********
# Epoch 141, Loss: 55.0834 +/- 16.5884, Time: 0.57
#
# #################### Train ####################
# Epoch 142, Loss: 53.6578 +/- 14.8947, Time: 2.26
# ********** Validate **********
# Epoch 142, Loss: 54.5094 +/- 16.1092, Time: 0.47
#
# #################### Train ####################
# Epoch 143, Loss: 53.8394 +/- 14.9768, Time: 2.19
# ********** Validate **********
# Epoch 143, Loss: 54.5150 +/- 16.3060, Time: 0.47
#
# #################### Train ####################
# Epoch 144, Loss: 53.5356 +/- 14.9510, Time: 2.24
# ********** Validate **********
# Epoch 144, Loss: 54.9937 +/- 16.2234, Time: 0.48
#
# #################### Train ####################
# Epoch 145, Loss: 53.1749 +/- 13.9998, Time: 2.41
# ********** Validate **********
# Epoch 145, Loss: 55.2205 +/- 16.1513, Time: 0.69
#
# #################### Train ####################
# Epoch 146, Loss: 53.2111 +/- 14.7604, Time: 2.36
# ********** Validate **********
# Epoch 146, Loss: 54.1559 +/- 15.9072, Time: 0.46
#
# #################### Train ####################
# Epoch 147, Loss: 52.9392 +/- 14.8358, Time: 2.17
# ********** Validate **********
# Epoch 147, Loss: 54.5615 +/- 15.6379, Time: 0.45
#
# #################### Train ####################
# Epoch 148, Loss: 53.4085 +/- 14.5536, Time: 2.18
# ********** Validate **********
# Epoch 148, Loss: 55.3182 +/- 16.5347, Time: 0.46
#
# #################### Train ####################
# Epoch 149, Loss: 53.3514 +/- 15.0734, Time: 2.21
# ********** Validate **********
# Epoch 149, Loss: 55.2993 +/- 15.9124, Time: 0.55
#
# #################### Train ####################
# Epoch 150, Loss: 53.3682 +/- 14.1191, Time: 2.61
# ********** Validate **********
# Epoch 150, Loss: 54.2445 +/- 16.0518, Time: 0.45
#
# #################### Train ####################
# Epoch 151, Loss: 52.9549 +/- 14.3259, Time: 2.21
# ********** Validate **********
# Epoch 151, Loss: 53.7904 +/- 16.3771, Time: 0.47
#
# #################### Train ####################
# Epoch 152, Loss: 53.2891 +/- 15.2843, Time: 2.25
# ********** Validate **********
# Epoch 152, Loss: 54.7670 +/- 16.2512, Time: 0.46
#
# #################### Train ####################
# Epoch 153, Loss: 53.1946 +/- 14.7884, Time: 2.17
# ********** Validate **********
# Epoch 153, Loss: 53.3122 +/- 16.4690, Time: 0.47
#
# #################### Train ####################
# Epoch 154, Loss: 52.9477 +/- 14.8642, Time: 2.61
# ********** Validate **********
# Epoch 154, Loss: 54.5799 +/- 16.1490, Time: 0.57
#
# #################### Train ####################
# Epoch 155, Loss: 52.6652 +/- 14.1009, Time: 2.18
# ********** Validate **********
# Epoch 155, Loss: 53.5107 +/- 16.3712, Time: 0.46
#
# #################### Train ####################
# Epoch 156, Loss: 52.6048 +/- 14.3445, Time: 2.18
# ********** Validate **********
# Epoch 156, Loss: 52.9528 +/- 16.5856, Time: 0.47
#
# #################### Train ####################
# Epoch 157, Loss: 52.4541 +/- 14.6053, Time: 2.24
# ********** Validate **********
# Epoch 157, Loss: 54.9643 +/- 16.4856, Time: 0.45
#
# #################### Train ####################
# Epoch 158, Loss: 52.3762 +/- 13.8484, Time: 2.37
# ********** Validate **********
# Epoch 158, Loss: 54.4500 +/- 16.3575, Time: 0.67
#
# #################### Train ####################
# Epoch 159, Loss: 52.3983 +/- 15.0998, Time: 2.43
# ********** Validate **********
# Epoch 159, Loss: 52.8630 +/- 15.8194, Time: 0.47
#
# #################### Train ####################
# Epoch 160, Loss: 52.2307 +/- 13.8598, Time: 2.18
# ********** Validate **********
# Epoch 160, Loss: 54.3372 +/- 16.3109, Time: 0.44
#
# #################### Train ####################
# Epoch 161, Loss: 52.4912 +/- 14.1877, Time: 2.20
# ********** Validate **********
# Epoch 161, Loss: 54.7200 +/- 15.8241, Time: 0.47
#
# #################### Train ####################
# Epoch 162, Loss: 52.3888 +/- 14.4427, Time: 2.25
# ********** Validate **********
# Epoch 162, Loss: 54.1611 +/- 15.9851, Time: 0.44
#
# #################### Train ####################
# Epoch 163, Loss: 52.2967 +/- 15.3950, Time: 2.76
# ********** Validate **********
# Epoch 163, Loss: 53.0088 +/- 16.3051, Time: 0.49
#
# #################### Train ####################
# Epoch 164, Loss: 51.6607 +/- 14.4585, Time: 2.25
# ********** Validate **********
# Epoch 164, Loss: 52.9882 +/- 15.9335, Time: 0.46
#
# #################### Train ####################
# Epoch 165, Loss: 51.8794 +/- 13.4106, Time: 2.18
# ********** Validate **********
# Epoch 165, Loss: 53.1199 +/- 16.0358, Time: 0.46
#
# #################### Train ####################
# Epoch 166, Loss: 51.2644 +/- 13.7667, Time: 2.18
# ********** Validate **********
# Epoch 166, Loss: 52.8555 +/- 15.7163, Time: 0.44
#
# #################### Train ####################
# Epoch 167, Loss: 51.0086 +/- 13.8198, Time: 2.56
# ********** Validate **********
# Epoch 167, Loss: 52.8454 +/- 15.8528, Time: 0.66
#
# #################### Train ####################
# Epoch 168, Loss: 51.2014 +/- 13.9090, Time: 2.30
# ********** Validate **********
# Epoch 168, Loss: 52.7113 +/- 15.6065, Time: 0.43
#
# #################### Train ####################
# Epoch 169, Loss: 51.0277 +/- 14.1489, Time: 2.17
# ********** Validate **********
# Epoch 169, Loss: 52.3264 +/- 16.1527, Time: 0.47
#
# #################### Train ####################
# Epoch 170, Loss: 50.7359 +/- 14.1280, Time: 2.18
# ********** Validate **********
# Epoch 170, Loss: 52.4203 +/- 15.7113, Time: 0.46
#
# #################### Train ####################
# Epoch 171, Loss: 50.5653 +/- 13.9401, Time: 2.18
# ********** Validate **********
# Epoch 171, Loss: 53.7811 +/- 16.2452, Time: 0.68
#
# #################### Train ####################
# Epoch 172, Loss: 50.4995 +/- 14.2957, Time: 2.53
# ********** Validate **********
# Epoch 172, Loss: 52.4452 +/- 15.5371, Time: 0.47
#
# #################### Train ####################
# Epoch 189, Loss: 55.3937 +/- 16.1331, Time: 0.46
#
# #################### Train ####################
# Epoch 190, Loss: 50.9929 +/- 13.8122, Time: 2.20
# ********** Validate **********
# Epoch 190, Loss: 50.6509 +/- 14.9749, Time: 0.47
#
# #################### Train ####################
# Epoch 191, Loss: 51.2330 +/- 14.5171, Time: 2.20
# ********** Validate **********
# Epoch 191, Loss: 56.5111 +/- 15.3742, Time: 0.46
#
# #################### Train ####################
# Epoch 192, Loss: 51.7386 +/- 13.7954, Time: 2.24
# ********** Validate **********
# Epoch 192, Loss: 50.3426 +/- 14.7669, Time: 0.47
#
# #################### Train ####################
# Epoch 193, Loss: 51.0327 +/- 13.1551, Time: 2.54
# ********** Validate **********
# Epoch 193, Loss: 54.0627 +/- 15.9677, Time: 0.69
#
# #################### Train ####################
# Epoch 194, Loss: 51.4400 +/- 13.6783, Time: 2.28
# ********** Validate **********
# Epoch 194, Loss: 52.4837 +/- 14.1913, Time: 0.47
#
# #################### Train ####################
# Epoch 195, Loss: 50.6869 +/- 14.2331, Time: 2.29
# ********** Validate **********
# Epoch 195, Loss: 53.0822 +/- 15.3735, Time: 0.46
#
# #################### Train ####################
# Epoch 196, Loss: 51.3989 +/- 13.1678, Time: 2.23
# ********** Validate **********
# Epoch 196, Loss: 53.5969 +/- 15.5692, Time: 0.47
#
# #################### Train ####################
# Epoch 197, Loss: 49.8409 +/- 13.5829, Time: 2.30
# ********** Validate **********
# Epoch 197, Loss: 50.8429 +/- 14.9590, Time: 0.68
#
# #################### Train ####################
# Epoch 198, Loss: 49.8004 +/- 13.9183, Time: 2.50
# ********** Validate **********
# Epoch 198, Loss: 54.1918 +/- 14.9241, Time: 0.46
#
# #################### Train ####################
# Epoch 199, Loss: 49.7248 +/- 13.6110, Time: 2.17
# ********** Validate **********
# Epoch 199, Loss: 50.7109 +/- 14.9848, Time: 0.46

# %%
Xtest = torch.stack([tup[0] for tup in test_set])
Xtest = Xtest.to(args['device'])

ytest = torch.stack([tup[1] for tup in test_set])
ypred = net(Xtest).cpu().data

data = torch.cat((ytest, ypred), axis=1)

df_results = pd.DataFrame(data, columns=['ypred', 'ytest'])
df_results.head(20)
# Out:
#     ypred       ytest
# 0   352.0  351.675293
# 1   156.0  141.683929
# 2    12.0    7.166396
# 3     2.0   20.457254
# 4   391.0  361.358612
# 5   391.0  308.146271
# 6    84.0  152.692734
# 7   487.0  566.396545
# 8   176.0  248.737061
# 9   157.0   78.729645
# 10   82.0   85.355949
# 11  186.0  146.651123
# 12  277.0  271.932648
# 13  264.0  291.410400
# 14  312.0  315.657471
# 15   56.0   52.719440
# 16  370.0  176.248520
# 17   14.0    0.000000
# 18  124.0  191.078110
# 19  427.0  387.127380

# %% [markdown]
# # Gráfico de convergência

# %%
plt.figure(figsize=(20, 9))
plt.plot(train_losses, label='Train')
plt.plot(test_losses, label='Test', linewidth=3, alpha=0.5)
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.title('Convergence', fontsize=16)
plt.legend()
plt.show()
